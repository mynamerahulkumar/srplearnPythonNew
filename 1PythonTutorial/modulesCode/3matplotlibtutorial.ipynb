# %% [markdown]
# # matplotlib
# matplotlib is a crucial library when working with pandas because it provides powerful data visualization capabilities. Here’s its significance in pandas:
#
# 1. Visualization of DataFrames and Series:
#
# pandas has built-in plotting capabilities that rely on matplotlib (df.plot(), series.plot()).
#
# It allows users to create line plots, bar charts, histograms, scatter plots, and more directly from DataFrames and Series.
#
# 2. Customization and Control:
#
# matplotlib provides detailed control over the appearance of plots, such as colors, labels, legends, and grid styles.
#
# You can fine-tune plots generated by pandas using matplotlib functions (e.g., plt.xlabel(), plt.title(), etc.).
#
# 3. Statistical and Exploratory Data Analysis:
#
# Helps in understanding trends, patterns, and distributions in data.
#
# Used for plotting histograms (df.hist()), box plots, and correlation heatmaps.
#
# 4. Integration with Other Libraries:
#
# Works well with seaborn, plotly, and pandas to create advanced visualizations.

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x1=np.linspace(0,10,100)

fig=plt.figure()
plt.plot(x1,np.sin(x1),'-')
plt.show()

# %%
# %matplotlib inline
x1=np.linspace(0,10,100)

fig=plt.figure()
plt.plot(x1,np.sin(x1),'-')
plt.show()

# %%
# %matplotlib inline
x1=np.linspace(0,10,100)

fig=plt.figure()
plt.plot(x1,np.sin(x1),'-')
plt.plot(x1,np.cos(x1),'--')
plt.show()

# %%
# %matplotlib inline
x1=np.linspace(0,10,100)

fig=plt.figure()
plt.subplot(2,1,1)#row,col,panel number
plt.plot(x1,np.sin(x1))
plt.subplot(2,1,2)
plt.plot(x1,np.cos(x1))
plt.show()

# %%
print(plt.gcf())
# Out:
# Figure(640x480)

# %%
plt.gca()
# Out:
# <Axes: >

# %% [markdown]
# # Visualization with Pyplot
#
# Generating visualization with Pyplot is very easy. The x-axis values ranges from 0-3 and the y-axis from 1-4. If we provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values, and automatically generates the x values. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3] and y data are [1,2,3,4].

# %%
plt.plot([1,2,3,4])
plt.ylabel('count')
plt.show()

# %%
plt.gcf()

# %%
plt.plot([1,2,3,4,5],[3,6,9,10,15])
plt.show()

# %% [markdown]
# # State-machine interface
#
# Pyplot provides the state-machine interface to the underlying object-oriented plotting library. The state-machine implicitly and automatically creates figures and axes to achieve the desired plot. For example:

# %%
x=np.linspace(0,2,100)
plt.plot(x,x,label='linear')
plt.plot(x,x*x,label='quadractic')
plt.plot(x,x*x*x,label='cubic')
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('simple plot')
plt.legend()
plt.show()

# %% [markdown]
# # Formatting the style of plot
#
# For every x, y pair of arguments, there is an optional third argument which is the format string that indicates the color and line type of the plot. The letters and symbols of the format string are from MATLAB. We can concatenate a color string with a line style string. The default format string is 'b-', which is a solid blue line. For example, to plot the above line with red circles, we would issue the following command:-

# %%
plt.plot([1,2,3,4,5],[1,4,9,15,20],'ro')
plt.axis([0,7,0,21])
plt.show()

# %% [markdown]
# # Working with NumPy arrays
#
# Generally, we have to work with NumPy arrays. All sequences are converted to numpy arrays internally. The below example illustrates plotting several lines with different format styles in one command using arrays.

# %%
x1=np.arange(0.0,5.0,0.2)

plt.plot(x1,x1,'r--',x1,x1*x1,'bs',x1,x1*x1*x1,'g^')
plt.show()

# %% [markdown]
# # Object-Oriented API
#
# The Object-Oriented API is available for more complex plotting situations. It allows us to exercise more control over the figure. In Pyplot API, we depend on some notion of an "active" figure or axes. But, in the Object-Oriented API the plotting functions are methods of explicit Figure and Axes objects.
#
# Figure is the top level container for all the plot elements. We can think of the Figure object as a box-like container containing one or more Axes.
#
# The Axes represent an individual plot. The Axes object contain smaller objects such as axis, tick marks, lines, legends, title and text-boxes.
#
# The following code produces sine and cosine curves using Object-Oriented API.

# %%
fig,ax=plt.subplots(2)
x1=np.linspace(0,2,10)

ax[0].plot(x1,np.sin(x1),'-')
ax[1].plot(x1,np.cos(x1))
plt.show()

# %% [markdown]
# # Plot with Matplotlib

# %%
plt.plot([1,2,5,7],'b-')
plt.show()

# %%
x=np.arange(0.0,8.0,0.01)
plt.plot(x,[num*num for num in x],'b-')
plt.show()

# %% [markdown]
# # Multiline Plots

# %%
x1=range(1,6)
plt.plot(x1,[ x*1.5 for x in x1])
plt.plot(x1,[x2*4 for x2 in x1])
plt.plot(x1,[x3*5 for x3 in x1])
plt.show()

# %% [markdown]
# # Line Plot

# %%
fig=plt.figure()
ax=plt.axes()
x1=np.linspace(0,20,100)

ax.plot(x1,np.sin(x1),'b-')
fig.savefig('sinegraph.png')
plt.show()

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format',
#  'webp': 'WebP Image Format'}

# %% [markdown]
# # Scatter Plot

# %%
x=np.linspace(0,10,40)
y=np.sin(x)
plt.plot(x,y,'o',color='red')
plt.show()

# %% [markdown]
# # Histogram

# %%
data=np.random.randn(2000)
plt.hist(data)
plt.show()

# %%
data
# Out:
# array([-1.01352772, -0.46031634, -1.41761188, ...,  1.48105014,
#        -0.78500609,  0.78815559])

# %% [markdown]
#  # Bar Chart

# %%
data=[5,20,45,65]
plt.bar(range(len(data)),data)
plt.show()

# %%
data=[5,20,45,65]
plt.barh(range(len(data)),data)
plt.show()

# %% [markdown]
# # Stacked Bar Chart

# %%
a = [15., 30., 45., 22.]

b = [15., 25., 50., 20.]

z=range(4)
plt.bar(z,a,color='b')
plt.bar(z,b,color='r',bottom=a)
plt.show()

# %% [markdown]
# # Pie Chart

# %%
plt.figure(figsize=(8,8))
x=[20,40,30,10]
labels=['Electronics','Computer','Mechanical','Chemical']
plt.pie(x,labels=labels,autopct='%1.1f%%')
plt.legend()
plt.show()

# %% [markdown]
# # Boxplot

# %%
data=np.random.rand(100)
plt.boxplot(data)
plt.show()

# %%
data
# Out:
# array([0.39334693, 0.06881374, 0.87087619, 0.18204775, 0.54809521,
#        0.8702596 , 0.93297256, 0.99655262, 0.24038011, 0.38971774,
#        0.48117685, 0.33465496, 0.87462933, 0.33076904, 0.82066915,
#        0.0781537 , 0.79785046, 0.63706719, 0.86425724, 0.85815878,
#        0.37634328, 0.85480751, 0.94436208, 0.25823892, 0.71293041,
#        0.67074433, 0.79536451, 0.37839458, 0.04374126, 0.69667801,
#        0.93887141, 0.06563216, 0.10796035, 0.1972013 , 0.20130756,
#        0.8306144 , 0.80067982, 0.48970036, 0.29612688, 0.87407955,
#        0.71735563, 0.27342065, 0.70361691, 0.73798962, 0.75702498,
#        0.27667535, 0.41804424, 0.58301902, 0.4403669 , 0.66418824,
#        0.93524678, 0.2120035 , 0.70753126, 0.15792697, 0.78831541,
#        0.21665432, 0.94414368, 0.72966182, 0.65728233, 0.97759593,
#        0.89709842, 0.43856347, 0.38193119, 0.16365106, 0.183141  ,
#        0.37598584, 0.57719501, 0.74020437, 0.85423952, 0.65017415,
#        0.71956664, 0.97547935, 0.32118233, 0.33396032, 0.70652313,
#        0.57775087, 0.34509701, 0.83916451, 0.23405528, 0.79506835,
#        0.46144436, 0.50329969, 0.5191923 , 0.36362218, 0.31160026,
#        0.4474989 , 0.81919606, 0.8728809 , 0.00132736, 0.66225362,
#        0.49903322, 0.60209957, 0.99150969, 0.85676076, 0.13512771,
#        0.06771768, 0.27382447, 0.98908426, 0.1218468 , 0.45780252])

# %% [markdown]
# # Area Chart

# %%
x=range(1,6)
y=[1,4,6,8,4]
plt.fill_between(x,y)
plt.show()

# %% [markdown]
# # Adding a grid

# %%
x=np.arange(1,5)
plt.plot(x,x*x,x,x*2.5,x,x*1.5)
plt.grid(True)
plt.xlabel('Class number')
plt.title('Class count')
plt.ylabel('count')
plt.show()

# %%
x=np.arange(1,5)
x
# Out:
# array([1, 2, 3, 4])
